# %%
! conda info --env
# Out:
# # conda environments:
# #
# base                  *  C:\Users\ADE\miniconda3
# active_learn             C:\Users\ADE\miniconda3\envs\active_learn
# compaira                 C:\Users\ADE\miniconda3\envs\compaira
# dbconnect                C:\Users\ADE\miniconda3\envs\dbconnect
# mvin                     C:\Users\ADE\miniconda3\envs\mvin
# pgpr                     C:\Users\ADE\miniconda3\envs\pgpr
# py310                    C:\Users\ADE\miniconda3\envs\py310
# rec_sys                  C:\Users\ADE\miniconda3\envs\rec_sys
# recbole_env              C:\Users\ADE\miniconda3\envs\recbole_env
# recoxplainer             C:\Users\ADE\miniconda3\envs\recoxplainer
# tensorflow               C:\Users\ADE\miniconda3\envs\tensorflow
# tsa_course               C:\Users\ADE\miniconda3\envs\tsa_course
# wflow                    C:\Users\ADE\miniconda3\envs\wflow

# %%
! pip list
# Out:
# Package                Version             Location
# ---------------------- ------------------- -------------------------------------------------------
# anyio                  2.2.0
# argcomplete            2.0.0
# argon2-cffi            20.1.0
# async-generator        1.10
# attrs                  20.3.0
# Babel                  2.9.1
# backcall               0.2.0
# bleach                 3.3.0
# blinker                1.6.2
# brotlipy               0.7.0
# certifi                2020.12.5
# cffi                   1.14.4
# chardet                3.0.4
# click                  8.1.3
# cloudpickle            2.0.0
# colorama               0.4.4
# conda                  4.10.1
# conda-package-handling 1.7.2
# cryptography           3.3.1
# cycler                 0.10.0
# dash                   2.9.3
# dash-core-components   2.0.0
# dash-html-components   2.0.0
# dash-table             5.0.0
# decorator              5.0.6
# defusedxml             0.7.1
# deprecation            2.1.0
# ...
